# %% [markdown]
# <a href="https://colab.research.google.com/github/ElnazDi/colab/blob/master/Data_Visualization_NC2C_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import seaborn as sns

import pandas as pd

from google.colab import files

# %%
files.upload()

# %%
data= pd.read_csv('candy.csv', index_col='id')
data.head()
# Out:
#    competitorname chocolate fruity  ... sugarpercent pricepercent winpercent
# id                                  ...
# 0       100 Grand       Yes     No  ...        0.732        0.860  66.971725
# 1    3 Musketeers       Yes     No  ...        0.604        0.511  67.602936
# 2       Air Heads        No    Yes  ...        0.906        0.511  52.341465
# 3      Almond Joy       Yes     No  ...        0.465        0.767  50.347546
# 4       Baby Ruth       Yes     No  ...        0.604        0.767  56.914547
#
# [5 rows x 13 columns]

# %%
list(data.columns)
# Out:
# ['competitorname',
#  'chocolate',
#  'fruity',
#  'caramel',
#  'peanutyalmondy',
#  'nougat',
#  'crispedricewafer',
#  'hard',
#  'bar',
#  'pluribus',
#  'sugarpercent',
#  'pricepercent',
#  'winpercent']

# %% [markdown]
# **Do people tend to prefer candies with higher sugar content?**
#
# The scatter plot does not show a strong correlation between the two variables. Since there is no clear relationship between the two variables, this tells us that sugar content does not play a strong role in candy popularity.

# %%
sns.scatterplot(x=data['sugarpercent'] , y=data['winpercent'])

plt.xlabel('Suger')
plt.ylabel('Popularity')
plt.title('Popularity of Candy base on its suger')
# Out:
# Text(0.5, 1.0, 'Popularity of Candy base on its suger')

# %%
sns.regplot(x=data['sugarpercent'] , y=data['winpercent'])

plt.xlabel('Suger')
plt.ylabel('Popularity')
plt.title('Popularity of Candy base on its suger')
# Out:
# Text(0.5, 1.0, 'Popularity of Candy base on its suger')

# %% [markdown]
# Since the regression line has a slightly **positive slope**, this tells us that there is a **slightly positive correlation between 'winpercent' and 'sugarpercent'**. Thus, people have a slight preference for candies containing relatively more sugar.

# %% [markdown]
# Create a scatter plot to show the relationship between `'pricepercent'` (on the horizontal x-axis) and `'winpercent'` (on the vertical y-axis).
#
# Use the `'chocolate'` column to color-code the points.

# %%
sns.scatterplot(x=data['pricepercent'] , y=data['winpercent'], hue=data['chocolate'])

plt.xlabel('Price')
plt.ylabel('Popularity')
plt.title('Popularity of Candy base on its price')
# Out:
# Text(0.5, 1.0, 'Popularity of Candy base on its price')

# %% [markdown]
# Create the same scatter plot you created in last section, but now with two regression lines, corresponding to (1) chocolate candies and (2) candies without chocolate.

# %%
sns.lmplot(x='pricepercent' , y='winpercent', hue='chocolate', data=data)

plt.xlabel('Price')
plt.ylabel('Popularity')
plt.title('Popularity of Candy base on its Price and chocolate')
# Out:
# Text(0.5, 1.0, 'Popularity of Candy base on its Price and chocolate')

# %% [markdown]
# We'll begin with the regression line for chocolate candies. Since this line has a slightly positive slope, we can say that more expensive chocolate candies tend to be more popular (than relatively cheaper chocolate candies). Likewise, since the regression line for candies without chocolate has a negative slope, we can say that if candies don't contain chocolate, they tend to be more popular when they are cheaper. One important note, however, is that the dataset is quite small -- so we shouldn't invest too much trust in these patterns! To inspire more confidence in the results, we should add more candies to the dataset.

# %% [markdown]
# Create a categorical scatter plot to highlight the relationship between `'chocolate'` and `'winpercent'`.  Put `'chocolate'` on the (horizontal) x-axis, and `'winpercent'` on the (vertical) y-axis.

# %%
sns.swarmplot(x=data['chocolate'] , y=data['winpercent'])

plt.xlabel('Chocolate')
plt.ylabel('Popularity')
plt.title('Popularity of Candy base on its Chocolate')
# Out:
# Text(0.5, 1.0, 'Popularity of Candy base on its Chocolate')
