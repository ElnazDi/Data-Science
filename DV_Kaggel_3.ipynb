# %% [markdown]
# <a href="https://colab.research.google.com/github/ElnazDi/colab/blob/master/DV_Kaggel_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-26cdc8fd-9b6b-4d5c-a727-c386f3588c69" name="files[]" multiple disabled />
#      <output id="result-26cdc8fd-9b6b-4d5c-a727-c386f3588c69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving flight_delays.csv to flight_delays.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('flight_delays.csv', index_col= 'Month')
data
# Out:
#              AA        AS         B6  ...        US         VX         WN
# Month                                 ...
# 1      6.955843 -0.320888   7.347281  ...  3.107457   1.420702   3.389466
# 2      7.530204 -0.782923  18.657673  ...  7.114455   7.784410   3.501363
# 3      6.693587 -0.544731  10.741317  ...  3.330787   5.348207   3.263341
# 4      4.931778 -3.009003   2.780105  ...  2.660290   0.995507   2.996399
# 5      5.173878 -1.716398  -0.709019  ...  0.681605   7.102021   5.680777
# 6      8.191017 -0.220621   5.047155  ...  5.766296   5.779415  10.743462
# 7      3.870440  0.377408   5.841454  ...       NaN   7.135773  10.504942
# 8      3.193907  2.503899   9.280950  ...       NaN   5.106221   5.532108
# 9     -1.432732 -1.813800   3.539154  ...       NaN   0.070998  -1.336260
# 10    -0.580930 -2.993617   3.676787  ...       NaN   2.254278  -0.688851
# 11     0.772630 -1.916516   1.418299  ...       NaN   0.116370   0.995684
# ...

# %%
plt.figure(figsize=(10,6))
plt.title('Average delay for NK flight by month')
sns.barplot(x=data.index , y=data.NK ) #or y=data['NK'] but not for index
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=data, annot=True)
plt.xlabel('Flights')
plt.title("Average Arrival Delay for Each Airline, by Month")
# Out:
# Text(0.5, 1, 'Average Arrival Delay for Each Airline, by Month')
