# %% [markdown]
# <a href="https://colab.research.google.com/github/ElnazDi/colab/blob/master/DV_Kaggel_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data= files.upload()
# Out:
#      <input type="file" id="files-eebcdcdf-34aa-4139-997d-f12d3f20b639" name="files[]" multiple disabled />
#      <output id="result-eebcdcdf-34aa-4139-997d-f12d3f20b639">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving spotify.csv to spotify.csv

# %%
import pandas as pd
spotify = pd.read_csv('spotify.csv', index_col='Date', parse_dates=True)
spotify.head()
# Out:
#             Shape of You  Despacito  ...  HUMBLE.  Unforgettable
# Date                                 ...
# 2017-01-06      12287078        NaN  ...      NaN            NaN
# 2017-01-07      13190270        NaN  ...      NaN            NaN
# 2017-01-08      13099919        NaN  ...      NaN            NaN
# 2017-01-09      14506351        NaN  ...      NaN            NaN
# 2017-01-10      14275628        NaN  ...      NaN            NaN
#
# [5 rows x 5 columns]

# %%
spotify.tail()
# Out:
#             Shape of You  Despacito  ...    HUMBLE.  Unforgettable
# Date                                 ...
# 2018-01-05       4492978  3450315.0  ...  2685857.0      2869783.0
# 2018-01-06       4416476  3394284.0  ...  2559044.0      2743748.0
# 2018-01-07       4009104  3020789.0  ...  2350985.0      2441045.0
# 2018-01-08       4135505  2755266.0  ...  2523265.0      2622693.0
# 2018-01-09       4168506  2791601.0  ...  2727678.0      2627334.0
#
# [5 rows x 5 columns]

# %%
from matplotlib import pyplot as pyplot
import seaborn as sns
# %matplotlib inline

# %%
plot = sns.lineplot(data=spotify)

# %%
plt.figure(figsize=(14,6))
plt.xlabel('Dates')
plt.ylabel('Number of streaming')
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify)   
# Important to write underneath of every plt..... otherwise it will show two diffrent plot one empty one little fully

# %%
spotify.columns
# Out:
# Index(['Shape of You', 'Despacito', 'Something Just Like This', 'HUMBLE.',
#        'Unforgettable'],
#       dtype='object')

# %%
# we want to plot the lines corresponding to the first two columns in the dataset.
plt.figure(figsize=(14,6))
plt.xlabel('Dates')
plt.ylabel('Number of streaming')
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify['Shape of You'], label= 'Shape of You')
sns.lineplot(data=spotify['Despacito'], label= 'Despacito')
