# %% [markdown]
# <a href="https://colab.research.google.com/github/ElnazDi/colab/blob/master/Data_Visualization_NC2C_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-e1baae88-64c6-4138-a24d-985454b1f659" name="files[]" multiple disabled />
#      <output id="result-e1baae88-64c6-4138-a24d-985454b1f659">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving museum_visitors.csv to museum_visitors.csv
# ...

# %%
data = pd.read_csv('museum_visitors.csv', index_col ='Date', parse_dates=True)
data.head()   #The first 5 rows
# Out:
#             Avila Adobe  ...  America Tropical Interpretive Center
# Date                     ...
# 2014-01-01        24778  ...                                  6602
# 2014-02-01        18976  ...                                  5029
# 2014-03-01        25231  ...                                  8129
# 2014-04-01        26989  ...                                  2824
# 2014-05-01        36883  ...                                 10694
#
# [5 rows x 4 columns]

# %%
data.tail() #The last five rows
# Out:
#             Avila Adobe  ...  America Tropical Interpretive Center
# Date                     ...
# 2018-07-01        23136  ...                                  4718
# 2018-08-01        20815  ...                                  3891
# 2018-09-01        21020  ...                                  3180
# 2018-10-01        19280  ...                                  3775
# 2018-11-01        17163  ...                                  4562
#
# [5 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['Avila Adobe', 'Firehouse Museum', 'Chinese American Museum',
#        'America Tropical Interpretive Center'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['Avila Adobe',
#  'Firehouse Museum',
#  'Chinese American Museum',
#  'America Tropical Interpretive Center']

# %%
plt.figure(figsize=(13,6))
sns.lineplot(data=data)
plt.title("Monthly Visitors to Los Angeles City Museums")
#plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Monthly Visitors to Los Angeles City Museums')

# %%
plt.figure(figsize=(13,6))
sns.lineplot(data=data['Firehouse Museum'], label='Firehouse Museum')
plt.title('Monthly Visitors to Firehouse Museum')
# Out:
# Text(0.5, 1.0, 'Monthly Visitors to Firehouse Museum')

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark-palette', 'seaborn-deep', 'Solarize_Light2', '_classic_test', 'ggplot', 'seaborn-darkgrid', 'seaborn', 'tableau-colorblind10', 'seaborn-white', 'seaborn-colorblind', 'seaborn-muted', 'seaborn-talk', 'fast', 'bmh', 'seaborn-whitegrid', 'seaborn-dark', 'seaborn-pastel', 'seaborn-notebook', 'seaborn-poster', 'seaborn-bright', 'dark_background', 'seaborn-paper', 'seaborn-ticks', 'grayscale', 'classic', 'fivethirtyeight']

# %%
plt.style.use('seaborn')

# %%
plt.figure(figsize=(13,6))
sns.lineplot(data=data['Firehouse Museum'], label='Firehouse Museum')
sns.lineplot(data=data['America Tropical Interpretive Center'], label='America Tropical Interpretive Center')

plt.title('Monthly Visitors to Firehouse Museum')
# Out:
# Text(0.5, 1.0, 'Monthly Visitors to Firehouse Museum')
