# %% [markdown]
# <a href="https://colab.research.google.com/github/ElnazDi/colab/blob/master/Matplotlib_Pie_Charts_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
print(plt.style.available)
# Out:
# ['seaborn', 'seaborn-deep', 'seaborn-dark', 'seaborn-paper', 'dark_background', 'Solarize_Light2', 'grayscale', 'bmh', 'seaborn-talk', 'seaborn-pastel', 'seaborn-muted', 'seaborn-notebook', 'ggplot', 'seaborn-white', 'tableau-colorblind10', 'seaborn-bright', 'seaborn-darkgrid', 'classic', '_classic_test', 'fast', 'seaborn-whitegrid', 'seaborn-ticks', 'seaborn-dark-palette', 'seaborn-colorblind', 'fivethirtyeight', 'seaborn-poster']

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# [wedge matplotlib documentation](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.patches.Wedge.html)

# %%
slices=[60,40]
labels=['Sixty','Forty']
plt.pie(slices, labels = labels, wedgeprops={'edgecolor':'black'} )

plt.title('My Awsome Pie Chart')
plt.tight_layout()
plt.show()

# %%
slices=[120,80,30,20]
labels=['Sixty','Forty','Extra_1','Extrea_2']
colors=['green','yellow','gray','pink']
plt.pie(slices, labels = labels, colors=colors, wedgeprops={'edgecolor':'black'} )

plt.title('My Awsome Pie Chart')
plt.tight_layout()
plt.show()

# %%
# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917, 31991, 27097, 23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell', 'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']

plt.pie(slices, labels = labels, wedgeprops={'edgecolor':'black'} )

plt.title('My Awsome Pie Chart')
plt.tight_layout()
plt.show()

# %%
# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode=[0,0,0,0.1,0]

plt.pie(slices, labels = labels, explode=explode, shadow= True, startangle=90, wedgeprops={'edgecolor':'black'} )

plt.title('My Awsome Pie Chart')
plt.tight_layout()
plt.show()

# %%
# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode=[0,0,0,0.1,0]

plt.pie(slices, labels = labels, explode=explode, shadow= True, startangle=90, autopct='%1.1f%%', wedgeprops={'edgecolor':'black'} )

plt.title('My Awsome Pie Chart')
plt.tight_layout()
plt.show()
